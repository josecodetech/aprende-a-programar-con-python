# %% [markdown]
# Crea un fichero y guarda un texto en el, despues abrelo y recupera el texto.

# %% [markdown]
# Serializa un diccionario usando pickle.(si no has visto pickle anteriormente, busca en la documentacion oficial)
