# %% [markdown]
# Crea un modulo con las operaciones basicas (suma, resta, multiplicacion, division), importalo desde otro archivo y realiza las operaciones con las llamadas a las funciones creadas.

# %% [markdown]
# Crea un modulo que contenga la funcion saludo pasandole como parametro un nombre y llamala desde otro archivo.
